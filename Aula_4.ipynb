# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('cursos-prouni.csv')
df.head()
# Out:
#           grau     turno  mensalidade  bolsa_integral_cotas  \
# 0  Bacharelado  Integral      9999.99                  15.0
# 1  Bacharelado   Noturno      9836.40                   1.0
# 2  Bacharelado  Integral      9715.61                   2.0
# 3  Bacharelado   Noturno      9689.34                   3.0
# 4  Bacharelado  Integral      9674.34                   4.0
#
#    bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 0                  14.0                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   5.0                  6.0                 10.0
# 3                   2.0                  NaN                  NaN
# 4                   1.0                  5.0                  2.0
#
#           curso_id curso_busca  cidade_busca uf_busca     cidade_filtro  \
# 0     706710394154    Medicina  Campo Grande       MS  NTAwMjAwNDAyNzA0
# ...

# %%
# Contagem por grau
df['grau'].value_counts()
# Out:
# Bacharelado     19165
# Tecnológico     13480
# Licenciatura     8802
# Name: grau, dtype: int64

# %%
# Mostra o tamanho do DataFrame (linha, colunas)
df.shape
# Out:
# (41447, 20)

# %%
df.dtypes
# Out:
# grau                     object
# turno                    object
# mensalidade             float64
# bolsa_integral_cotas    float64
# bolsa_integral_ampla    float64
# bolsa_parcial_cotas     float64
# bolsa_parcial_ampla     float64
# curso_id                  int64
# curso_busca              object
# cidade_busca             object
# uf_busca                 object
# cidade_filtro            object
# universidade_nome        object
# campus_nome              object
# campus_id                 int64
# nome                     object
# nota_integral_ampla     float64
# nota_integral_cotas     float64
# nota_parcial_ampla      float64
# nota_parcial_cotas      float64
# dtype: object

# %%
# gráfico referente ao gráu;
df['grau'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='grau'>

# %%
# contagem referente ao grau e turno;
df[['grau', 'turno']].value_counts()
# Out:
# grau          turno
# Tecnológico   Curso a Distância    9723
# Bacharelado   Noturno              8200
# Licenciatura  Curso a Distância    7088
# Bacharelado   Curso a Distância    6115
#               Matutino             3852
# Tecnológico   Noturno              2688
# Licenciatura  Noturno              1308
# Tecnológico   Matutino              977
# Bacharelado   Integral              587
#               Vespertino            411
# Licenciatura  Matutino              346
# Tecnológico   Vespertino             68
# Licenciatura  Vespertino             31
#               Integral               29
# Tecnológico   Integral               24
# dtype: int64

# %%
df_grau_bacharelado = df[df['grau'] == "Bacharelado"]
df_grau_bacharelado[['turno']].value_counts()
# Out:
# turno
# Noturno              8200
# Curso a Distância    6115
# Matutino             3852
# Integral              587
# Vespertino            411
# dtype: int64

# %%
df_grau_bacharelado[['turno']].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='None'>

# %%
# arquivo bem formatado com mensalidade tipo float
df[df['mensalidade'] > 5000]
# Out:
#             grau     turno  mensalidade  bolsa_integral_cotas  \
# 0    Bacharelado  Integral      9999.99                  15.0
# 1    Bacharelado   Noturno      9836.40                   1.0
# 2    Bacharelado  Integral      9715.61                   2.0
# 3    Bacharelado   Noturno      9689.34                   3.0
# 4    Bacharelado  Integral      9674.34                   4.0
# ..           ...       ...          ...                   ...
# 140  Bacharelado   Noturno      5394.00                   0.0
# 141  Bacharelado   Noturno      5367.60                   0.0
# 142  Bacharelado   Noturno      5324.40                   NaN
# 143  Bacharelado  Integral      5256.20                   1.0
# 144  Bacharelado  Integral      5220.85                  14.0
#
#      bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 0                    14.0                  NaN                  NaN
# 1                     NaN                  NaN                  NaN
# ...

# %%
df['nome'].value_counts().head(10)
# Out:
# Administração                            2754
# Pedagogia                                2555
# Ciências Contábeis                       2056
# Gestão de Recursos Humanos               1595
# Educação Física                          1528
# Serviço Social                           1166
# Direito                                  1093
# Logística                                1042
# Processos Gerenciais                     1011
# Análise e Desenvolvimento de Sistemas    1008
# Name: nome, dtype: int64

# %%
df[df['nome'] == 'Administração'][['cidade_busca']].value_counts()
# Out:
# cidade_busca
# Sao Paulo         132
# Brasilia           64
# Curitiba           52
# Belo Horizonte     52
# Rio de Janeiro     42
#                  ...
# Jaiba               1
# Jandaia do Sul      1
# Jaragua             1
# Jardim              1
# Xique-Xique         1
# Length: 870, dtype: int64

# %%
df[df['nome'] == 'Administração'][['cidade_busca']].head(10).value_counts()
# Out:
# cidade_busca
# Rio de Janeiro    5
# Curitiba          2
# Cafelandia        1
# Campinas          1
# Porto Alegre      1
# dtype: int64

# %%
df['nome'].value_counts().head(10).plot.barh()
# Out:
# <AxesSubplot:>
